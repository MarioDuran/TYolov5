# %%
# !nvidia-smi
# Out:
# Thu Nov 26 09:27:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Benchmark

# %% [markdown]
# ConvLSTM

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/1 ConvLSTM/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp0/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp0/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 152 layers, 3.20299e+07 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 16893.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [02:13<00:00,  7.19it/s]
#                  all         960    3.17e+03       0.579       0.891       0.885       0.556
# Speed: 17.5/2.5/20.0 ms inference/NMS/total per 640x640 image at batch-size 1

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/2 MConvLSTM/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp0/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp0/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 200 layers, 7.72231e+07 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 16592.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [01:43<00:00,  9.30it/s]
#                  all         960    3.17e+03       0.603       0.905       0.907       0.597
# Speed: 31.3/2.5/33.8 ms inference/NMS/total per 640x640 image at batch-size 1

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/3 LConvLSTM/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp0/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp0/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 248 layers, 1.46477e+08 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 15301.75it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [01:59<00:00,  8.01it/s]
#                  all         960    3.17e+03        0.63       0.903       0.907         0.6
# Speed: 49.3/2.5/51.9 ms inference/NMS/total per 640x640 image at batch-size 1

# %% [markdown]
# QRNN

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/4 SQRNN/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp4/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp4/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 158 layers, 2.58367e+07 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 15090.48it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [01:27<00:00, 10.98it/s]
#                  all         960    3.17e+03       0.577       0.886       0.883       0.559
# Speed: 17.1/2.4/19.5 ms inference/NMS/total per 640x640 image at batch-size 1

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/5 MQRNN/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp3/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp3/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 206 layers, 6.32886e+07 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 17673.02it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [01:39<00:00,  9.68it/s]
#                  all         960    3.17e+03       0.603       0.905       0.907        0.59
# Speed: 29.7/2.4/32.2 ms inference/NMS/total per 640x640 image at batch-size 1

# %%
import os
os.chdir("/content/drive/My Drive/Tesis/Paper/6 LQRNN/yolov5")

# %%
# !python test.py --fp --data ./data/coco_7000_5000.yaml --batch-size 1 --weights runs/exp3/weights/best.pt
# Out:
# Namespace(augment=False, batch_size=1, cfg='models/yolov5xc.yaml', conf_thres=0.001, data='./data/coco_7000_5000.yaml', device='', fp=True, hyp='data/hyp.finetune.yaml', img_size=640, iou_thres=0.65, save_json=False, save_txt=False, seq_len=2, single_cls=False, task='val', verbose=False, weights='runs/exp3/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 254 layers, 1.21704e+08 parameters, 0 gradients
# Scanning labels /content/coco_7000_5000/labels/val2017.cache (960 found, 0 missing, 0 empty, 0 duplicate, for 960 images): 960it [00:00, 15772.82it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 960/960 [01:51<00:00,  8.62it/s]
#                  all         960    3.17e+03       0.626       0.896       0.906       0.602
# Speed: 41.8/2.4/44.3 ms inference/NMS/total per 640x640 image at batch-size 1
